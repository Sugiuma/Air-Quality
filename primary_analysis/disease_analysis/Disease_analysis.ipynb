# %%
import pandas as pd

# Load the datasets
df_disease = pd.read_csv("../../data/idsp.csv", encoding='ISO-8859-1')
df_aqi = pd.read_csv("../../data/aqi.csv")

# Standardize column names
df_disease.rename(columns={
    'year': 'Year',
    'state': 'State',
    'disease_illness_name': 'Disease',
    'cases': 'Cases'
}, inplace=True)

df_aqi.rename(columns={
    'date': 'Date',
    'state': 'State',
    'aqi_value': 'AQI'
}, inplace=True)

# Clean up: parse types
#df_disease['Year'] = df_disease['Year'].astype(int)
# Clean and parse dates correctly
df_aqi['Date'] = pd.to_datetime(df_aqi['Date'], dayfirst=True, errors='coerce')
df_aqi['Year'] = df_aqi['Date'].dt.year
df_aqi['Month'] = df_aqi['Date'].dt.month

df_disease['Date'] = pd.to_datetime(df_disease['outbreak_starting_date'], dayfirst=True, errors='coerce')
df_disease['Year'] = df_disease['Date'].dt.year
df_disease['Month'] = df_disease['Date'].dt.month

#print(df_disease)

# Get last 3 years from disease data
latest_year = df_disease['Year'].max()
last_3_years = [latest_year - i for i in range(3)]

# After filtering, make a copy before assigning new columns
recent_disease = df_disease[df_disease['Year'].isin(last_3_years)].copy()
recent_aqi = df_aqi[df_aqi['Year'].isin(last_3_years)].copy()

# Step 1: Total disease cases per state & disease (last 3 years)
state_disease_cases = (
    recent_disease.groupby(['State', 'Disease'])['Cases']
    .sum()
    .reset_index()
)

# Step 2: Rank diseases within each state to get top 2
state_disease_cases['Rank'] = (
    state_disease_cases.groupby('State')['Cases']
    .rank(method='first', ascending=False)
)

top2_diseases_per_state = state_disease_cases[state_disease_cases['Rank'] <= 2]

# Step 3: Compute average AQI per state over last 3 years
avg_aqi_per_state = (
    recent_aqi.groupby('State')['AQI']
    .mean()
    .reset_index()
    .rename(columns={'AQI': 'Avg_AQI'})
)

# Step 4: Merge top 2 diseases per state with average AQI
final_df = pd.merge(top2_diseases_per_state, avg_aqi_per_state, on='State', how='left')

# Step 5: Sort for readability
final_df = final_df.sort_values(by=['State', 'Rank'])

# Step 6: Pivot diseases and cases into separate columns per rank
disease_cases_pivot = (
    top2_diseases_per_state.pivot(index='State', columns='Rank', values=['Disease', 'Cases'])
)

# Flatten MultiIndex columns
disease_cases_pivot.columns = ['Disease1', 'Disease2', 'Cases1', 'Cases2']
disease_cases_pivot = disease_cases_pivot.reset_index()

# Step 7: Merge with average AQI
final_result = pd.merge(disease_cases_pivot, avg_aqi_per_state, on='State', how='left')

# Step 8: Sort for readability
final_result = final_result.sort_values('State')

# Step 9: Display or save
print(final_result)
final_result.to_csv("top2_diseases_cases_aqi.csv", index=False)
# Out:
#                                        State                        Disease1  \
# 0                Andaman and Nicobar Islands         Acute Diarrheal Disease
# 1                             Andhra Pradesh         Acute Diarrheal Disease
# 2                                  Arunachal                          Rabies
# 3                          Arunachal Pradesh         Acute Diarrheal Disease
# 4                                      Assam         Acute Diarrheal Disease
# 5                                      Bihar         Acute Diarrheal Disease
# 6                                 Chandigarh                         Cholera
# 7                               Chhattisgarh         Acute Diarrheal Disease
# 8                     Dadra and Nagar Haveli  Fever of Unknown andigin (PUO)
# 9   Dadra and Nagar Haveli and Daman and Diu                  Food Poisoning
# 10                                     Delhi                          Dengue
# 11                                       Goa                         Cholera
# 12                                   Gujarat         Acute Diarrheal Disease
# 13                                   Haryana                         Cholera
# 14                          Himachal Pradesh         Acute Diarrheal Disease
# 15                         Jammu and Kashmir                          Dengue
# 16                                 Jharkhand                         Malaria
# 17                                 Karnataka         Acute Diarrheal Disease
# 18                                    Kerala                  Food Poisoning
# 19                                    Ladakh                           Mumps
# 20                                    Madhya                         Measles
# 21                            Madhya Pradesh         Acute Diarrheal Disease
# 22                               Maharashtra         Acute Diarrheal Disease
# 23                                   Manipur                          Dengue
# 24                                 Meghalaya                         Measles
# 25                                   Mizoram                  Food Poisoning
# 26                                  Nagaland                          Dengue
# 27                                    Odisha         Acute Diarrheal Disease
# 28                                Puducherry         Acute Diarrheal Disease
# 29                                    Punjab         Acute Diarrheal Disease
# 30                                 Rajasthan         Acute Diarrheal Disease
# 31                                    Sikkim                        Jaundice
# 32                                Tamil Nadu         Acute Diarrheal Disease
# 33                                Tamil nadu                           Mumps
# 34                                 Telangana         Acute Diarrheal Disease
# 35                                   Tripura         Acute Diarrheal Disease
# 36                                     Uttar                    Human Rabies
# 37                             Uttar Pradesh         Acute Diarrheal Disease
# 38                               Uttarakhand                          Dengue
# 39                               West Bengal         Acute Diarrheal Disease
#
#                        Disease2 Cases1 Cases2     Avg_AQI
# 0               Fever with Rash     94      8   57.706897
# 1                       Cholera   3189   1081   78.529013
# 2                           NaN      1    NaN         NaN
# 3                         Mumps    290    133   55.961207
# 4                Food Poisoning   2683   1791  116.733009
# 5               Fever with Rash   1316    830  153.262618
# 6                           NaN     16    NaN  145.118824
# 7                       Cholera   7818    745   79.577185
# 8       Acute Diarrheal Disease    101     72         NaN
# 9       Acute Diarrheal Disease     24     13         NaN
# 10                          NaN     40    NaN  208.852941
# 11               Food Poisoning    226     63         NaN
# 12                      Cholera   4826   2287  109.187765
# 13      Acute Diarrheal Disease    972    696  136.862528
# 14                  Hepatitis A   2181    559  161.011111
# 15                  Hepatitis A   1474   1140   69.714976
# 16      Acute Diarrheal Disease   5795   1609  165.854725
# 17                      Cholera   6332   3616   63.513838
# 18      Acute Diarrheal Disease   9342   4756   69.434137
# 19  Hand Foot and Mouth Disease    111     52         NaN
# 20                   Chickenpox     36      7         NaN
# 21                       Dengue   5752   2207  108.762673
# 22               Food Poisoning   6771   4382  103.443939
# 23               Food Poisoning   3072    147  107.439024
# 24                   Chickenpox    586    318   73.540584
# 25                 Scrub Typhus    339    233   51.522207
# 26      Acute Diarrheal Disease   1244     72   83.431479
# 27                      Cholera   5495   3427  124.595860
# 28                       Dengue     80     72   56.647131
# 29                      Cholera    889    715  117.094933
# 30                       Dengue   1185    836  128.221318
# 31                      Typhoid    136    111   59.202744
# 32                        Mumps   3028   1416   68.001633
# 33                          NaN     14    NaN         NaN
# 34               Food Poisoning    604     25   81.911765
# 35                       Dengue    390    259  143.618922
# 36                          NaN      1    NaN         NaN
# 37               Food Poisoning   4140   2218  123.688452
# 38      Acute Diarrheal Disease   1092    626   88.100917
# 39               Food Poisoning   3276   2360  117.816071
